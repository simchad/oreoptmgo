# %% [markdown]
# Recommended Name - Submission Name 둘 중 하나 가짐.
#
# alternative name 은 옵션

# %%
# Recommended or Submission Name 불러오기. ProteinDecription 없으면 Deleted.
import json
import os
import pandas as pd


with open('C:/Users/simhc/Downloads/idmapping_2024_08_05.json', 'r') as f:
    json_data = json.load(f)

# Number of entries (from)
num_sublist = json_data['results'].__len__()

category_name = []
pr_names = []
entry_from = []

for n_try in range(num_sublist):
    data_dict = json_data["results"][n_try]
    name_dict = data_dict["to"]
    phrase = "Protein Name Joined..."

    print('Processing... %d : %s'%(n_try, data_dict["from"]))

    if name_dict.get("proteinDescription") == None:
        entry_from.append(data_dict["from"])
        category_name.append("Deleted")
        pr_names.append('Deleted')
        print(phrase)

    else:
        try:
            pr_name = name_dict['proteinDescription']['recommendedName']['fullName']['value']
            entry_from.append(data_dict["from"])
            category_name.append('recommendedName')
            pr_names.append(pr_name)
            print(phrase)
        except:
            pr_name =name_dict['proteinDescription']['submissionNames'][0]['fullName']['value']
            entry_from.append(data_dict["from"])
            category_name.append('submissionNames')
            pr_names.append(pr_name)
            print(phrase)

df_protname = pd.DataFrame({'From': entry_from,
                            'Category': category_name,
                            'Protein Name': pr_names
                            })

df_protname.to_csv(path_or_buf='C:/Users/simhc/Downloads/ProteinName_20240805.CSV', index=None, encoding='utf-8')
# Out:
# Processing... 0 : Q8R4Y8
# Protein Name Joined...
# Processing... 1 : Q80UU9
# Protein Name Joined...
# Processing... 2 : Q9JJI8
# Protein Name Joined...
# Processing... 3 : A2AMS3
# Protein Name Joined...
# Processing... 4 : Q9D1D4
# Protein Name Joined...
# Processing... 5 : Q283N4
# Protein Name Joined...
# Processing... 6 : P62855
# Protein Name Joined...
# Processing... 7 : Q91YM4
# Protein Name Joined...
# Processing... 8 : Q91YS7
# Protein Name Joined...
# Processing... 9 : Q62264
# Protein Name Joined...
# Processing... 10 : Q8VCC2
# Protein Name Joined...
# Processing... 11 : Q921H8
# Protein Name Joined...
# Processing... 12 : P35436
# Protein Name Joined...
# Processing... 13 : Q9CQE8
# Protein Name Joined...
# Processing... 14 : P23589
# Protein Name Joined...
# Processing... 15 : P61750
# Protein Name Joined...
# Processing... 16 : Q9D023
# Protein Name Joined...
# Processing... 17 : A2ADY9
# Protein Name Joined...
# Processing... 18 : Q9R1P0
# Protein Name Joined...
# Processing... 19 : Q9DB29
# Protein Name Joined...
# Processing... 20 : Q99K23
# Protein Name Joined...
# Processing... 21 : Q8CC86
# Protein Name Joined...
# Processing... 22 : P84228
# Protein Name Joined...
# Processing... 23 : Q91X91
# Protein Name Joined...
# Processing... 24 : P61804
# Protein Name Joined...
# Processing... 25 : O88325
# Protein Name Joined...
# Processing... 26 : D3YWT0
# Protein Name Joined...
# Processing... 27 : A0A2I3BRB9
# Protein Name Joined...
# Processing... 28 : A0A1L1SS90
# Protein Name Joined...
# Processing... 29 : Q9DCS2
# Protein Name Joined...
# Processing... 30 : A0A0R4J1N3
# Protein Name Joined...
# Processing... 31 : Q8K4H1
# Protein Name Joined...
# Processing... 32 : Q91WT9
# Protein Name Joined...
# Processing... 33 : Q9CQR2
# Protein Name Joined...
# Processing... 34 : A2AL12
# Protein Name Joined...
# Processing... 35 : Q9DCG6
# Protein Name Joined...
# Processing... 36 : P97351
# Protein Name Joined...
# Processing... 37 : P46978
# Protein Name Joined...
# Processing... 38 : Q91Z53
# Protein Name Joined...
# Processing... 39 : Q8QZR5
# Protein Name Joined...
# Processing... 40 : Q6IRU5
# Protein Name Joined...
# Processing... 41 : Q00PI9
# Protein Name Joined...
# Processing... 42 : P16406
# Protein Name Joined...
# Processing... 43 : G3UYV7
# Protein Name Joined...
# Processing... 44 : P62320
# Protein Name Joined...
# Processing... 45 : P60334
# Protein Name Joined...
# Processing... 46 : F6W2Q5
# Protein Name Joined...
# Processing... 47 : Q60936
# Protein Name Joined...
# Processing... 48 : P49443
# Protein Name Joined...
# Processing... 49 : P12787
# Protein Name Joined...
# Processing... 50 : Q9WTI7
# Protein Name Joined...
# Processing... 51 : A0A0R4J0I6
# Protein Name Joined...
# Processing... 52 : P35979
# Protein Name Joined...
# Processing... 53 : Q9CXF0
# Protein Name Joined...
# Processing... 54 : Q5F285
# Protein Name Joined...
# Processing... 55 : P21440
# Protein Name Joined...
# Processing... 56 : F6SMH4
# Protein Name Joined...
# Processing... 57 : P35486
# Protein Name Joined...
# Processing... 58 : Q921I1
# Protein Name Joined...
# Processing... 59 : Q61702
# Protein Name Joined...
# Processing... 60 : P21619
# Protein Name Joined...
# Processing... 61 : Q91XH6
# Protein Name Joined...
# Processing... 62 : P06728
# Protein Name Joined...
# Processing... 63 : Q8BKZ9
# Protein Name Joined...
# Processing... 64 : Q9CRD0
# Protein Name Joined...
# Processing... 65 : Q9DCX2
# Protein Name Joined...
# Processing... 66 : D3Z0F3
# Protein Name Joined...
# Processing... 67 : Q9CU62
# Protein Name Joined...
# Processing... 68 : P70195
# Protein Name Joined...
# Processing... 69 : P26443
# Protein Name Joined...
# Processing... 70 : Q9EQ06
# Protein Name Joined...
# Processing... 71 : A0A0N4SWI4
# Protein Name Joined...
# Processing... 72 : Z4YK03
# Protein Name Joined...
# Processing... 73 : P01899
# Protein Name Joined...
# Processing... 74 : E9Q3V2
# Protein Name Joined...
# Processing... 75 : P62889
# Protein Name Joined...
# Processing... 76 : Q9CZU6
# Protein Name Joined...
# Processing... 77 : A0A075B5P4
# Protein Name Joined...
# Processing... 78 : Q03311
# Protein Name Joined...
# Processing... 79 : P55050
# Protein Name Joined...
# Processing... 80 : Q8VBW8
# Protein Name Joined...
# Processing... 81 : Q99LM2
# Protein Name Joined...
# Processing... 82 : Q3TMH2
# Protein Name Joined...
# Processing... 83 : Q9JMD3
# Protein Name Joined...
# Processing... 84 : P16675
# Protein Name Joined...
# Processing... 85 : P62281
# Protein Name Joined...
# Processing... 86 : O35215
# Protein Name Joined...
# Processing... 87 : Q9JKB1
# Protein Name Joined...
# Processing... 88 : Q8BFZ9
# Protein Name Joined...
# Processing... 89 : Q9CPQ1
# Protein Name Joined...
# Processing... 90 : Q9CQ92
# Protein Name Joined...
# Processing... 91 : Q3U4W8
# Protein Name Joined...
# Processing... 92 : P00688
# Protein Name Joined...
# Processing... 93 : Q3TLP5
# Protein Name Joined...
# Processing... 94 : F6ZHD8
# Protein Name Joined...
# Processing... 95 : Q91WN4
# Protein Name Joined...
# Processing... 96 : Q9DCT2
# Protein Name Joined...
# Processing... 97 : Q8JZN5
# Protein Name Joined...
# Processing... 98 : P14246
# Protein Name Joined...
# Processing... 99 : G5E850
# Protein Name Joined...
# Processing... 100 : E9PYH3
# Protein Name Joined...
# Processing... 101 : P54869
# Protein Name Joined...
# Processing... 102 : Q9D517
# Protein Name Joined...
# Processing... 103 : P56135
# Protein Name Joined...
# Processing... 104 : Q9CYW4
# Protein Name Joined...
# Processing... 105 : Q91X34
# Protein Name Joined...
# Processing... 106 : G3UW94
# Protein Name Joined...
# Processing... 107 : A0A0R4J140
# Protein Name Joined...
# Processing... 108 : Q91X77
# Protein Name Joined...
# Processing... 109 : P35282
# Protein Name Joined...
# Processing... 110 : P24456
# Protein Name Joined...
# Processing... 111 : P14206
# Protein Name Joined...
# Processing... 112 : P48678
# Protein Name Joined...
# Processing... 113 : Q9Z2X1
# Protein Name Joined...
# Processing... 114 : P26043
# Protein Name Joined...
# Processing... 115 : Q99N42
# Protein Name Joined...
# Processing... 116 : Q9CXW3
# Protein Name Joined...
# Processing... 117 : Q9CQF9
# Protein Name Joined...
# Processing... 118 : Q9DCC5
# Protein Name Joined...
# Processing... 119 : Q91YR1
# Protein Name Joined...
# Processing... 120 : Q61247
# Protein Name Joined...
# Processing... 121 : Q9D662
# Protein Name Joined...
# Processing... 122 : Q9CQM5
# Protein Name Joined...
# Processing... 123 : Q9ERS2
# Protein Name Joined...
# Processing... 124 : Q9Z1N5
# Protein Name Joined...
# Processing... 125 : C5NSA7
# Protein Name Joined...
# Processing... 126 : Q91VU6
# Protein Name Joined...
# Processing... 127 : A0A0R4J0P1
# Protein Name Joined...
# Processing... 128 : Q9R1P3
# Protein Name Joined...
# Processing... 129 : Q99JX4
# Protein Name Joined...
# Processing... 130 : Q9R1P1
# Protein Name Joined...
# Processing... 131 : Q91XE4
# Protein Name Joined...
# Processing... 132 : B1AWE0
# Protein Name Joined...
# Processing... 133 : P29758
# Protein Name Joined...
# Processing... 134 : Q9CQN7
# Protein Name Joined...
# Processing... 135 : Q8VIJ6
# Protein Name Joined...
# Processing... 136 : P48722
# Protein Name Joined...
# Processing... 137 : P53986
# Protein Name Joined...
# Processing... 138 : Q8R1A8
# Protein Name Joined...
# Processing... 139 : Q5YD48
# Protein Name Joined...
# Processing... 140 : Q3ULD5
# Protein Name Joined...
# Processing... 141 : P97384
# Protein Name Joined...
# Processing... 142 : Q9DCW4
# Protein Name Joined...
# Processing... 143 : E9QND8
# Protein Name Joined...
# Processing... 144 : P62869
# Protein Name Joined...
# Processing... 145 : Q9EQF5
# Protein Name Joined...
# Processing... 146 : Q9D6Z1
# Protein Name Joined...
# Processing... 147 : Q9QYC7
# Protein Name Joined...
# Processing... 148 : Q7TSH2
# Protein Name Joined...
# Processing... 149 : A0A075B6A3
# Protein Name Joined...
# Processing... 150 : Q9CQQ7
# Protein Name Joined...
# Processing... 151 : P54822
# Protein Name Joined...
# Processing... 152 : E9Q397
# Protein Name Joined...
# Processing... 153 : O09172
# Protein Name Joined...
# Processing... 154 : E9Q175
# Protein Name Joined...
# Processing... 155 : P46061
# Protein Name Joined...
# Processing... 156 : P19253
# Protein Name Joined...
# Processing... 157 : Q9Z2Z6
# Protein Name Joined...
# Processing... 158 : P43883
# Protein Name Joined...
# Processing... 159 : J7NUP1
# Protein Name Joined...
# Processing... 160 : Q64310
# Protein Name Joined...
# Processing... 161 : P52792
# Protein Name Joined...
# Processing... 162 : Q9Z2M7
# Protein Name Joined...
# Processing... 163 : Q63880
# Protein Name Joined...
# Processing... 164 : P08226
# Protein Name Joined...
# Processing... 165 : G3X982
# Protein Name Joined...
# Processing... 166 : P12382
# Protein Name Joined...
# Processing... 167 : O08795
# Protein Name Joined...
# Processing... 168 : P01872
# Protein Name Joined...
# Processing... 169 : Q9CWJ9
# Protein Name Joined...
# Processing... 170 : Q61656
# Protein Name Joined...
# Processing... 171 : Q9QZD8
# Protein Name Joined...
# Processing... 172 : P47199
# Protein Name Joined...
# Processing... 173 : Q99KF1
# Protein Name Joined...
# Processing... 174 : Q80XN0
# Protein Name Joined...
# Processing... 175 : P97742
# Protein Name Joined...
# Processing... 176 : A0A087WRE7
# Protein Name Joined...
# Processing... 177 : P70245
# Protein Name Joined...
# Processing... 178 : Q61335
# Protein Name Joined...
# Processing... 179 : Q8BP67
# Protein Name Joined...
# Processing... 180 : Q6PDN3
# Protein Name Joined...
# Processing... 181 : Q9Z2V4
# Protein Name Joined...
# Processing... 182 : O35678
# Protein Name Joined...
# Processing... 183 : P52825
# Protein Name Joined...
# Processing... 184 : Q9JHI5
# Protein Name Joined...
# Processing... 185 : D3YUW7
# Protein Name Joined...
# Processing... 186 : Q8VHE0
# Protein Name Joined...
# Processing... 187 : G5E8E1
# Protein Name Joined...
# Processing... 188 : P47757
# Protein Name Joined...
# Processing... 189 : P10922
# Protein Name Joined...
# Processing... 190 : Q9D6S7
# Protein Name Joined...
# Processing... 191 : Q08857
# Protein Name Joined...
# Processing... 192 : P50285
# Protein Name Joined...
# Processing... 193 : Q9DC50
# Protein Name Joined...
# Processing... 194 : Q8VCZ9
# Protein Name Joined...
# Processing... 195 : P61620
# Protein Name Joined...
# Processing... 196 : Q62093
# Protein Name Joined...
# Processing... 197 : Q8R1V4
# Protein Name Joined...
# Processing... 198 : Q02248
# Protein Name Joined...
# Processing... 199 : P62754
# Protein Name Joined...
# Processing... 200 : E9Q3V6
# Protein Name Joined...
# Processing... 201 : Q8BWW3
# Protein Name Joined...
# Processing... 202 : A2A6U5
# Protein Name Joined...
# Processing... 203 : Q64521
# Protein Name Joined...
# Processing... 204 : P58044
# Protein Name Joined...
# Processing... 205 : Q91X52
# Protein Name Joined...
# Processing... 206 : Q64435
# Protein Name Joined...
# Processing... 207 : P14576
# Protein Name Joined...
# Processing... 208 : Q05421
# Protein Name Joined...
# Processing... 209 : Q9JM62
# Protein Name Joined...
# Processing... 210 : Q5U458
# Protein Name Joined...
# Processing... 211 : F8VQC1
# Protein Name Joined...
# Processing... 212 : P70694
# Protein Name Joined...
# Processing... 213 : P35278
# Protein Name Joined...
# Processing... 214 : Q99LX0
# Protein Name Joined...
# Processing... 215 : P60766
# Protein Name Joined...
# Processing... 216 : Q61578
# Protein Name Joined...
# Processing... 217 : P10518
# Protein Name Joined...
# Processing... 218 : P24369
# Protein Name Joined...
# Processing... 219 : P07356
# Protein Name Joined...
# Processing... 220 : O35459
# Protein Name Joined...
# Processing... 221 : Q9CPW4
# Protein Name Joined...
# Processing... 222 : O70435
# Protein Name Joined...
# Processing... 223 : Q8C0Z1
# Protein Name Joined...
# Processing... 224 : D3Z316
# Protein Name Joined...
# Processing... 225 : P38060
# Protein Name Joined...
# Processing... 226 : P85094
# Protein Name Joined...
# Processing... 227 : Q9CYH2
# Protein Name Joined...
# Processing... 228 : D3YUM1
# Protein Name Joined...
# Processing... 229 : F8VPN4
# Protein Name Joined...
# Processing... 230 : P17742
# Protein Name Joined...
# Processing... 231 : Q9DC61
# Protein Name Joined...
# Processing... 232 : Q3UGC7
# Protein Name Joined...
# Processing... 233 : P34022
# Protein Name Joined...
# Processing... 234 : Q9DCM2
# Protein Name Joined...
# Processing... 235 : B0R091
# Protein Name Joined...
# Processing... 236 : Q5SV41
# Protein Name Joined...
# Processing... 237 : Q99LB2
# Protein Name Joined...
# Processing... 238 : Q8BJW6
# Protein Name Joined...
# Processing... 239 : Q9R0A0
# Protein Name Joined...
# Processing... 240 : P04919
# Protein Name Joined...
# Processing... 241 : P05064
# Protein Name Joined...
# Processing... 242 : E9QLB2
# Protein Name Joined...
# Processing... 243 : Q8R1B4
# Protein Name Joined...
# Processing... 244 : A0A0G2JDL3
# Protein Name Joined...
# Processing... 245 : Q8VEK0
# Protein Name Joined...
# Processing... 246 : Q9CQC6
# Protein Name Joined...
# Processing... 247 : O35386
# Protein Name Joined...
# Processing... 248 : Q3UPL0
# Protein Name Joined...
# Processing... 249 : P42232
# Protein Name Joined...
# Processing... 250 : Q8R081
# Protein Name Joined...
# Processing... 251 : Q9D8V0
# Protein Name Joined...
# Processing... 252 : Q9WUR9
# Protein Name Joined...
# Processing... 253 : Q9CY27
# Protein Name Joined...
# Processing... 254 : Q3UED7
# Protein Name Joined...
# Processing... 255 : S4R2B0
# Protein Name Joined...
# Processing... 256 : E9PWY9
# Protein Name Joined...
# Processing... 257 : Q9D8W7
# Protein Name Joined...
# Processing... 258 : Q04447
# Protein Name Joined...
# Processing... 259 : Q9JIF7
# Protein Name Joined...
# Processing... 260 : E9QNH6
# Protein Name Joined...
# Processing... 261 : P46656
# Protein Name Joined...
# Processing... 262 : Q8BZR4
# Protein Name Joined...
# Processing... 263 : Q99JY0
# Protein Name Joined...
# Processing... 264 : Q8BML9
# Protein Name Joined...
# Processing... 265 : Q14C51
# Protein Name Joined...
# Processing... 266 : Q9R112
# Protein Name Joined...
# Processing... 267 : P54116
# Protein Name Joined...
# Processing... 268 : A0A0J9YUS5
# Protein Name Joined...
# Processing... 269 : H3BJ51
# Protein Name Joined...
# Processing... 270 : Q9CZY3
# Protein Name Joined...
# Processing... 271 : O08807
# Protein Name Joined...
# Processing... 272 : Q9QXD1
# Protein Name Joined...
# Processing... 273 : Q9EPK7
# Protein Name Joined...
# Processing... 274 : Q3UEG6
# Protein Name Joined...
# Processing... 275 : P14131
# Protein Name Joined...
# Processing... 276 : Q3THW5
# Protein Name Joined...
# Processing... 277 : Q9Z2W0
# Protein Name Joined...
# Processing... 278 : Q9CWK8
# Protein Name Joined...
# Processing... 279 : Q60605
# Protein Name Joined...
# Processing... 280 : A2ABY3
# Protein Name Joined...
# Processing... 281 : Q91ZE0
# Protein Name Joined...
# Processing... 282 : Q9CQC7
# Protein Name Joined...
# Processing... 283 : A2AQA9
# Protein Name Joined...
# Processing... 284 : Q60692
# Protein Name Joined...
# Processing... 285 : P62073
# Protein Name Joined...
# Processing... 286 : Q9CRB9
# Protein Name Joined...
# Processing... 287 : Q8CFX1
# Protein Name Joined...
# Processing... 288 : Q9DBA8
# Protein Name Joined...
# Processing... 289 : P22892
# Protein Name Joined...
# Processing... 290 : A0A0G2JG10
# Protein Name Joined...
# Processing... 291 : Q8VBV7
# Protein Name Joined...
# Processing... 292 : O89079
# Protein Name Joined...
# Processing... 293 : P10639
# Protein Name Joined...
# Processing... 294 : Q9Z211
# Protein Name Joined...
# Processing... 295 : P47911
# Protein Name Joined...
# Processing... 296 : Q99020
# Protein Name Joined...
# Processing... 297 : Q8CC88
# Protein Name Joined...
# Processing... 298 : Q9D0M3
# Protein Name Joined...
# Processing... 299 : P53994
# Protein Name Joined...
# Processing... 300 : Q9CRB3
# Protein Name Joined...
# Processing... 301 : Q8CHR6
# Protein Name Joined...
# Processing... 302 : Q9Z0R9
# Protein Name Joined...
# Processing... 303 : Q3TNA1
# Protein Name Joined...
# Processing... 304 : Q9D1I5
# Protein Name Joined...
# Processing... 305 : Q9DAR7
# Protein Name Joined...
# Processing... 306 : Q99MN1
# Protein Name Joined...
# Processing... 307 : Q99KI3
# Protein Name Joined...
# Processing... 308 : M0QWP2
# Protein Name Joined...
# Processing... 309 : E9Q715
# Protein Name Joined...
# Processing... 310 : O35490
# Protein Name Joined...
# Processing... 311 : E9QA15
# Protein Name Joined...
# Processing... 312 : Q91XC9
# Protein Name Joined...
# Processing... 313 : Q61598
# Protein Name Joined...
# Processing... 314 : Q3TCH7
# Protein Name Joined...
# Processing... 315 : P28666
# Protein Name Joined...
# Processing... 316 : Q99JB2
# Protein Name Joined...
# Processing... 317 : Q8BP47
# Protein Name Joined...
# Processing... 318 : Q9CPP6
# Protein Name Joined...
# Processing... 319 : Q06890
# Protein Name Joined...
# Processing... 320 : Q9QYY9
# Protein Name Joined...
# Processing... 321 : Q78ZM0
# Protein Name Joined...
# Processing... 322 : Q8BWY3
# Protein Name Joined...
# Processing... 323 : Q9CXT8
# Protein Name Joined...
# Processing... 324 : Q00623
# Protein Name Joined...
# Processing... 325 : Q9D6K5
# Protein Name Joined...
# Processing... 326 : Q80VD1
# Protein Name Joined...
# Processing... 327 : Q8BGL3
# Protein Name Joined...
# Processing... 328 : P14733
# Protein Name Joined...
# Processing... 329 : O35129
# Protein Name Joined...
# Processing... 330 : P11930
# Protein Name Joined...
# Processing... 331 : Q5SUT0
# Protein Name Joined...
# Processing... 332 : A0A0J9YU79
# Protein Name Joined...
# Processing... 333 : A0A1L1SRY8
# Protein Name Joined...
# Processing... 334 : Q8VCX1
# Protein Name Joined...
# Processing... 335 : A0A0R4J0K1
# Protein Name Joined...
# Processing... 336 : A0A0R4J083
# Protein Name Joined...
# Processing... 337 : Q8CIE6
# Protein Name Joined...
# Processing... 338 : P0DP28
# Protein Name Joined...
# Processing... 339 : P63260
# Protein Name Joined...
# Processing... 340 : Q68FG2
# Protein Name Joined...
# Processing... 341 : P99026
# Protein Name Joined...
# Processing... 342 : Q8CBM2
# Protein Name Joined...
# Processing... 343 : Q9Z1D1
# Protein Name Joined...
# Processing... 344 : O35864
# Protein Name Joined...
# Processing... 345 : F6SVV1
# Protein Name Joined...
# Processing... 346 : Q9D1M7
# Protein Name Joined...
# Processing... 347 : B1ARW4
# Protein Name Joined...
# Processing... 348 : Q8C166
# Protein Name Joined...
# Processing... 349 : P16045
# Protein Name Joined...
# Processing... 350 : P46638
# Protein Name Joined...
# Processing... 351 : E9Q4G8
# Protein Name Joined...
# Processing... 352 : E9PYT3
# Protein Name Joined...
# Processing... 353 : P35980
# Protein Name Joined...
# Processing... 354 : P08113
# Protein Name Joined...
# Processing... 355 : A0A3B2WBH9
# Protein Name Joined...
# Processing... 356 : O55137
# Protein Name Joined...
# Processing... 357 : O09174
# Protein Name Joined...
# Processing... 358 : Q8R016
# Protein Name Joined...
# Processing... 359 : P05132
# Protein Name Joined...
# Processing... 360 : A0A0R4J119
# Protein Name Joined...
# Processing... 361 : Q91V41
# Protein Name Joined...
# Processing... 362 : A0A0R4J018
# Protein Name Joined...
# Processing... 363 : P58735
# Protein Name Joined...
# Processing... 364 : Q9Z2I0
# Protein Name Joined...
# Processing... 365 : Q8R5C5
# Protein Name Joined...
# Processing... 366 : Q91WG8
# Protein Name Joined...
# Processing... 367 : A0A0R4J1Z3
# Protein Name Joined...
# Processing... 368 : Q9D051
# Protein Name Joined...
# Processing... 369 : Q8R1S0
# Protein Name Joined...
# Processing... 370 : P12265
# Protein Name Joined...
# Processing... 371 : Q8VDJ3
# Protein Name Joined...
# Processing... 372 : Q9JMH6
# Protein Name Joined...
# Processing... 373 : Q9DBN5
# Protein Name Joined...
# Processing... 374 : Q9D0R2
# Protein Name Joined...
# Processing... 375 : Q9QXS1
# Protein Name Joined...
# Processing... 376 : Q2TPA8
# Protein Name Joined...
# Processing... 377 : Q9D1P4
# Protein Name Joined...
# Processing... 378 : Q9D880
# Protein Name Joined...
# Processing... 379 : Q9JIZ0
# Protein Name Joined...
# Processing... 380 : Q564E2
# Protein Name Joined...
# Processing... 381 : H7BX88
# Protein Name Joined...
# Processing... 382 : P32921
# Protein Name Joined...
# Processing... 383 : E9PUD2
# Protein Name Joined...
# Processing... 384 : Q8K310
# Protein Name Joined...
# Processing... 385 : Q9R1S7
# Protein Name Joined...
# Processing... 386 : Q9CXS4
# Protein Name Joined...
# Processing... 387 : Q9QYJ0
# Protein Name Joined...
# Processing... 388 : Q9CQN1
# Protein Name Joined...
# Processing... 389 : Q9D7J9
# Protein Name Joined...
# Processing... 390 : P34927
# Protein Name Joined...
# Processing... 391 : Q91VT4
# Protein Name Joined...
# Processing... 392 : P62908
# Protein Name Joined...
# Processing... 393 : Q9DBK0
# Protein Name Joined...
# Processing... 394 : Q9EP69
# Protein Name Joined...
# Processing... 395 : Q5U5V2
# Protein Name Joined...
# Processing... 396 : A0A1B0GRU8
# Protein Name Joined...
# Processing... 397 : P48036
# Protein Name Joined...
# Processing... 398 : Q99N15
# Protein Name Joined...
# Processing... 399 : Q8BU30
# Protein Name Joined...
# Processing... 400 : P23953
# Protein Name Joined...
# Processing... 401 : Q78PY7
# Protein Name Joined...
# Processing... 402 : Q6PF96
# Protein Name Joined...
# Processing... 403 : Q9CZW5
# Protein Name Joined...
# Processing... 404 : P97449
# Protein Name Joined...
# Processing... 405 : E9PZ00
# Protein Name Joined...
# Processing... 406 : P35279
# Protein Name Joined...
# Processing... 407 : F6SQH7
# Protein Name Joined...
# Processing... 408 : P62821
# Protein Name Joined...
# Processing... 409 : Q3UZZ6
# Protein Name Joined...
# Processing... 410 : G3X9T8
# Protein Name Joined...
# Processing... 411 : F6YVP7
# Protein Name Joined...
# Processing... 412 : Q3KQQ2
# Protein Name Joined...
# Processing... 413 : P13020
# Protein Name Joined...
# Processing... 414 : P07309
# Protein Name Joined...
# Processing... 415 : Q8BWP5
# Protein Name Joined...
# Processing... 416 : B1ASZ3
# Protein Name Joined...
# Processing... 417 : Q8R5I6
# Protein Name Joined...
# Processing... 418 : P36552
# Protein Name Joined...
# Processing... 419 : P55096
# Protein Name Joined...
# Processing... 420 : P24547
# Protein Name Joined...
# Processing... 421 : Q62167
# Protein Name Joined...
# Processing... 422 : P62983
# Protein Name Joined...
# Processing... 423 : E9Q855
# Protein Name Joined...
# Processing... 424 : Q9D826
# Protein Name Joined...
# Processing... 425 : Q6NXL1
# Protein Name Joined...
# Processing... 426 : Q9D7I5
# Protein Name Joined...
# Processing... 427 : O70194
# Protein Name Joined...
# Processing... 428 : P05202
# Protein Name Joined...
# Processing... 429 : Q6PAK3
# Protein Name Joined...
# Processing... 430 : Q3TDN2
# Protein Name Joined...
# Processing... 431 : P51150
# Protein Name Joined...
# Processing... 432 : A0A0N4SVQ1
# Protein Name Joined...
# Processing... 433 : Q7TPR4
# Protein Name Joined...
# Processing... 434 : Q64674
# Protein Name Joined...
# Processing... 435 : Q8BM55
# Protein Name Joined...
# Processing... 436 : P57759
# Protein Name Joined...
# Processing... 437 : P52480
# Protein Name Joined...
# Processing... 438 : O08914
# Protein Name Joined...
# Processing... 439 : Q8BH80
# Protein Name Joined...
# Processing... 440 : P56391
# Protein Name Joined...
# Processing... 441 : Q9D7N9
# Protein Name Joined...
# Processing... 442 : I7HLV2
# Protein Name Joined...
# Processing... 443 : Q91WS0
# Protein Name Joined...
# Processing... 444 : Q76LS9
# Protein Name Joined...
# Processing... 445 : Q8CHW4
# Protein Name Joined...
# Processing... 446 : O08810
# Protein Name Joined...
# Processing... 447 : Q9EQK5
# Protein Name Joined...
# Processing... 448 : Q9CQJ8
# Protein Name Joined...
# Processing... 449 : Q9QZD9
# Protein Name Joined...
# Processing... 450 : Q8VC81
# Protein Name Joined...
# Processing... 451 : Q04736
# Protein Name Joined...
# Processing... 452 : P62267
# Protein Name Joined...
# Processing... 453 : Q91YX5
# Protein Name Joined...
# Processing... 454 : P42227
# Protein Name Joined...
# Processing... 455 : Q9DBL7
# Protein Name Joined...
# Processing... 456 : Q05915
# Protein Name Joined...
# Processing... 457 : E9Q4Z2
# Protein Name Joined...
# Processing... 458 : P09103
# Protein Name Joined...
# Processing... 459 : P27046
# Protein Name Joined...
# Processing... 460 : Q8BWT1
# Protein Name Joined...
# Processing... 461 : Q9DCT1
# Protein Name Joined...
# Processing... 462 : Q99JB8
# Protein Name Joined...
# Processing... 463 : A0A2I3BQC0
# Protein Name Joined...
# Processing... 464 : P62900
# Protein Name Joined...
# Processing... 465 : Q91Y97
# Protein Name Joined...
# Processing... 466 : Q3TJI8
# Protein Name Joined...
# Processing... 467 : Q8R0V5
# Protein Name Joined...
# Processing... 468 : P60335
# Protein Name Joined...
# Processing... 469 : P70372
# Protein Name Joined...
# Processing... 470 : Q9CZR8
# Protein Name Joined...
# Processing... 471 : O88569
# Protein Name Joined...
# Processing... 472 : P26231
# Protein Name Joined...
# Processing... 473 : F8WJ41
# Protein Name Joined...
# Processing... 474 : D3Z2H7
# Protein Name Joined...
# Processing... 475 : Q68FL6
# Protein Name Joined...
# Processing... 476 : P63325
# Protein Name Joined...
# Processing... 477 : Q99L45
# Protein Name Joined...
# Processing... 478 : Q00896
# Protein Name Joined...
# Processing... 479 : P61514
# Protein Name Joined...
# Processing... 480 : Q8R0F8
# Protein Name Joined...
# Processing... 481 : Q64464
# Protein Name Joined...
# Processing... 482 : Q9DB20
# Protein Name Joined...
# Processing... 483 : Q924Y0
# Protein Name Joined...
# Processing... 484 : P84104
# Protein Name Joined...
# Processing... 485 : Q922Q8
# Protein Name Joined...
# Processing... 486 : Q9D5V6
# Protein Name Joined...
# Processing... 487 : P62827
# Protein Name Joined...
# Processing... 488 : Q64514
# Protein Name Joined...
# Processing... 489 : P15105
# Protein Name Joined...
# Processing... 490 : Q9JM76
# Protein Name Joined...
# Processing... 491 : P97429
# Protein Name Joined...
# Processing... 492 : Q9JII6
# Protein Name Joined...
# Processing... 493 : Q9DCV4
# Protein Name Joined...
# Processing... 494 : Q922Q1
# Protein Name Joined...
# Processing... 495 : Q8BU14
# Protein Name Joined...
# Processing... 496 : Q8BSE0
# Protein Name Joined...
# Processing... 497 : P62830
# Protein Name Joined...
# Processing... 498 : Q60866
# Protein Name Joined...
# Processing... 499 : P62918
# Protein Name Joined...
# Processing... 500 : Q8BH59
# Protein Name Joined...
# Processing... 501 : Q8JZZ0
# Protein Name Joined...
# Processing... 502 : Q80ZP8
# Protein Name Joined...
# Processing... 503 : Q9EPE9
# Protein Name Joined...
# Processing... 504 : P07901
# Protein Name Joined...
# Processing... 505 : P45952
# Protein Name Joined...
# Processing... 506 : Q99KK7
# Protein Name Joined...
# Processing... 507 : O08553
# Protein Name Joined...
# Processing... 508 : Q8BH95
# Protein Name Joined...
# Processing... 509 : O54734
# Protein Name Joined...
# Processing... 510 : Q8QZT1
# Protein Name Joined...
# Processing... 511 : Q91X72
# Protein Name Joined...
# Processing... 512 : O88451
# Protein Name Joined...
# Processing... 513 : A0A0R3P9C8
# Protein Name Joined...
# Processing... 514 : Q8BGJ5
# Protein Name Joined...
# Processing... 515 : P41317
# Protein Name Joined...
# Processing... 516 : P14685
# Protein Name Joined...
# Processing... 517 : P51660
# Protein Name Joined...
# Processing... 518 : E9Q1S3
# Protein Name Joined...
# Processing... 519 : P27659
# Protein Name Joined...
# Processing... 520 : Q9D6Y7
# Protein Name Joined...
# Processing... 521 : P28651
# Protein Name Joined...
# Processing... 522 : A0A0A6YX73
# Protein Name Joined...
# Processing... 523 : Q07417
# Protein Name Joined...
# Processing... 524 : D3Z2H9
# Protein Name Joined...
# Processing... 525 : Q9Z2I9
# Protein Name Joined...
# Processing... 526 : P68510
# Protein Name Joined...
# Processing... 527 : A0A0J9YUD8
# Protein Name Joined...
# Processing... 528 : G5E866
# Protein Name Joined...
# Processing... 529 : O35423
# Protein Name Joined...
# Processing... 530 : Q9CX34
# Protein Name Joined...
# Processing... 531 : Q5EBG8
# Protein Name Joined...
# Processing... 532 : Q9DBG3
# Protein Name Joined...
# Processing... 533 : Q60991
# Protein Name Joined...
# Processing... 534 : Q8K1Z0
# Protein Name Joined...
# Processing... 535 : P56593
# Protein Name Joined...
# Processing... 536 : P56376
# Protein Name Joined...
# Processing... 537 : P51658
# Protein Name Joined...
# Processing... 538 : Q9JKX3
# Protein Name Joined...
# Processing... 539 : A0A1W2P729
# Protein Name Joined...
# Processing... 540 : Q5SUH7
# Protein Name Joined...
# Processing... 541 : P16858
# Protein Name Joined...
# Processing... 542 : F8WIR1
# Protein Name Joined...
# Processing... 543 : Q61792
# Protein Name Joined...
# Processing... 544 : Q8CHQ9
# Protein Name Joined...
# Processing... 545 : Q9QXY6
# Protein Name Joined...
# Processing... 546 : P32020
# Protein Name Joined...
# Processing... 547 : P61290
# Protein Name Joined...
# Processing... 548 : Q3TML0
# Protein Name Joined...
# Processing... 549 : Q9CQ62
# Protein Name Joined...
# Processing... 550 : Q9DCH4
# Protein Name Joined...
# Processing... 551 : Q3TH01
# Protein Name Joined...
# Processing... 552 : E9Q5L2
# Protein Name Joined...
# Processing... 553 : Q9CQB4
# Protein Name Joined...
# Processing... 554 : P24270
# Protein Name Joined...
# Processing... 555 : A2ATI9
# Protein Name Joined...
# Processing... 556 : A2AKK5
# Protein Name Joined...
# Processing... 557 : P47802
# Protein Name Joined...
# Processing... 558 : Q8CHT0
# Protein Name Joined...
# Processing... 559 : P23116
# Protein Name Joined...
# Processing... 560 : Q6P3A8
# Protein Name Joined...
# Processing... 561 : O55234
# Protein Name Joined...
# Processing... 562 : A0A087WPL5
# Protein Name Joined...
# Processing... 563 : Q8K4F5
# Protein Name Joined...
# Processing... 564 : E9PV24
# Protein Name Joined...
# Processing... 565 : Q8R123
# Protein Name Joined...
# Processing... 566 : Q99JI4
# Protein Name Joined...
# Processing... 567 : F6RPJ9
# Protein Name Joined...
# Processing... 568 : P68373
# Protein Name Joined...
# Processing... 569 : Q91X83
# Protein Name Joined...
# Processing... 570 : Q9DB15
# Protein Name Joined...
# Processing... 571 : P43276
# Protein Name Joined...
# Processing... 572 : A2AJL3
# Protein Name Joined...
# Processing... 573 : Q8K411
# Protein Name Joined...
# Processing... 574 : A0A1C7CYV0
# Protein Name Joined...
# Processing... 575 : Q8BLN5
# Protein Name Joined...
# Processing... 576 : Q8VD00
# Protein Name Joined...
# Processing... 577 : Q9JHW4
# Protein Name Joined...
# Processing... 578 : G3X8P9
# Protein Name Joined...
# Processing... 579 : Q9WTX5
# Protein Name Joined...
# Processing... 580 : P56654
# Protein Name Joined...
# Processing... 581 : Q9QXD6
# Protein Name Joined...
# Processing... 582 : P28843
# Protein Name Joined...
# Processing... 583 : A2AN08
# Protein Name Joined...
# Processing... 584 : Q8BJ64
# Protein Name Joined...
# Processing... 585 : P28352
# Protein Name Joined...
# Processing... 586 : Q8BVQ0
# Protein Name Joined...
# Processing... 587 : Q6ZWN5
# Protein Name Joined...
# Processing... 588 : P62897
# Protein Name Joined...
# Processing... 589 : P49429
# Protein Name Joined...
# Processing... 590 : P42125
# Protein Name Joined...
# Processing... 591 : D3YUK4
# Protein Name Joined...
# Processing... 592 : Q9CQ40
# Protein Name Joined...
# Processing... 593 : Q8BU31
# Protein Name Joined...
# Processing... 594 : P63017
# Protein Name Joined...
# Processing... 595 : P47740
# Protein Name Joined...
# Processing... 596 : Q9JK53
# Protein Name Joined...
# Processing... 597 : Q8VCT4
# Protein Name Joined...
# Processing... 598 : D3YYM6
# Protein Name Joined...
# Processing... 599 : Q8VDN2
# Protein Name Joined...
# Processing... 600 : Q62446
# Protein Name Joined...
# Processing... 601 : Q8CG76
# Protein Name Joined...
# Processing... 602 : Q3U2P1
# Protein Name Joined...
# Processing... 603 : A0A0R4IZY2
# Protein Name Joined...
# Processing... 604 : Q8VCT3
# Protein Name Joined...
# Processing... 605 : P13439
# Protein Name Joined...
# Processing... 606 : Q8JZK9
# Protein Name Joined...
# Processing... 607 : H3BJP2
# Protein Name Joined...
# Processing... 608 : F6UFG6
# Protein Name Joined...
# Processing... 609 : Q62261
# Protein Name Joined...
# Processing... 610 : P63037
# Protein Name Joined...
# Processing... 611 : P80316
# Protein Name Joined...
# Processing... 612 : P58389
# Protein Name Joined...
# Processing... 613 : Q9WVD5
# Protein Name Joined...
# Processing... 614 : Q99LB7
# Protein Name Joined...
# Processing... 615 : P20152
# Protein Name Joined...
# Processing... 616 : Q9CR68
# Protein Name Joined...
# Processing... 617 : Q9CQ75
# Protein Name Joined...
# Processing... 618 : Q9CW42
# Protein Name Joined...
# Processing... 619 : P51881
# Protein Name Joined...
# Processing... 620 : O09061
# Protein Name Joined...
# Processing... 621 : P48774
# Protein Name Joined...
# Processing... 622 : Q8CAQ8
# Protein Name Joined...
# Processing... 623 : P17427
# Protein Name Joined...
# Processing... 624 : Q9WVK4
# Protein Name Joined...
# Processing... 625 : Q9EQ20
# Protein Name Joined...
# Processing... 626 : P16546
# Protein Name Joined...
# Processing... 627 : Q07456
# Protein Name Joined...
# Processing... 628 : Q8BUV3
# Protein Name Joined...
# Processing... 629 : Q60865
# Protein Name Joined...
# Processing... 630 : Q9Z204
# Protein Name Joined...
# Processing... 631 : Q8R0J2
# Protein Name Joined...
# Processing... 632 : A0A3B2WCD8
# Protein Name Joined...
# Processing... 633 : A2AUR7
# Protein Name Joined...
# Processing... 634 : Q7TMF3
# Protein Name Joined...
# Processing... 635 : O08738
# Protein Name Joined...
# Processing... 636 : Q3UF75
# Protein Name Joined...
# Processing... 637 : P15864
# Protein Name Joined...
# Processing... 638 : Q99LC3
# Protein Name Joined...
# Processing... 639 : P55264
# Protein Name Joined...
# Processing... 640 : Q07076
# Protein Name Joined...
# Processing... 641 : P67778
# Protein Name Joined...
# Processing... 642 : P52196
# Protein Name Joined...
# Processing... 643 : P62751
# Protein Name Joined...
# Processing... 644 : P58710
# Protein Name Joined...
# Processing... 645 : Q9CZ13
# Protein Name Joined...
# Processing... 646 : Q9CQM9
# Protein Name Joined...
# Processing... 647 : Q64374
# Protein Name Joined...
# Processing... 648 : P17563
# Protein Name Joined...
# Processing... 649 : Q9WV68
# Protein Name Joined...
# Processing... 650 : A0A0A6YXF6
# Protein Name Joined...
# Processing... 651 : Q9CY50
# Protein Name Joined...
# Processing... 652 : P23591
# Protein Name Joined...
# Processing... 653 : Q61768
# Protein Name Joined...
# Processing... 654 : Q4FE56
# Protein Name Joined...
# Processing... 655 : Q9CQU0
# Protein Name Joined...
# Processing... 656 : P20029
# Protein Name Joined...
# Processing... 657 : Q60931
# Protein Name Joined...
# Processing... 658 : Q64727
# Protein Name Joined...
# Processing... 659 : Q5XJY5
# Protein Name Joined...
# Processing... 660 : Q9JK38
# Protein Name Joined...
# Processing... 661 : A2A977
# Protein Name Joined...
# Processing... 662 : Q9D0E1
# Protein Name Joined...
# Processing... 663 : Q8VCH0
# Protein Name Joined...
# Processing... 664 : Q02053
# Protein Name Joined...
# Processing... 665 : Q8QZS1
# Protein Name Joined...
# Processing... 666 : Q6A0A9
# Protein Name Joined...
# Processing... 667 : P67984
# Protein Name Joined...
# Processing... 668 : Q61941
# Protein Name Joined...
# Processing... 669 : Q3THK7
# Protein Name Joined...
# Processing... 670 : Q7TMM9
# Protein Name Joined...
# Processing... 671 : Q9D5J6
# Protein Name Joined...
# Processing... 672 : Q64471
# Protein Name Joined...
# Processing... 673 : O35465
# Protein Name Joined...
# Processing... 674 : P21614
# Protein Name Joined...
# Processing... 675 : Q8VC28
# Protein Name Joined...
# Processing... 676 : P12970
# Protein Name Joined...
# Processing... 677 : Q6P5E4
# Protein Name Joined...
# Processing... 678 : P27612
# Protein Name Joined...
# Processing... 679 : A0A1L1STN8
# Protein Name Joined...
# Processing... 680 : Q925I1
# Protein Name Joined...
# Processing... 681 : A0A0J9YUI8
# Protein Name Joined...
# Processing... 682 : Q9QUM9
# Protein Name Joined...
# Processing... 683 : A0A0F6AIX6
# Protein Name Joined...
# Processing... 684 : Q9Z0N2
# Protein Name Joined...
# Processing... 685 : O08601
# Protein Name Joined...
# Processing... 686 : Q6NSR8
# Protein Name Joined...
# Processing... 687 : Q8BK72
# Protein Name Joined...
# Processing... 688 : O35226
# Protein Name Joined...
# Processing... 689 : Q3UXD9
# Protein Name Joined...
# Processing... 690 : O88844
# Protein Name Joined...
# Processing... 691 : Q3UJU9
# Protein Name Joined...
# Processing... 692 : A0A0R4J0I9
# Protein Name Joined...
# Processing... 693 : B7ZNJ1
# Protein Name Joined...
# Processing... 694 : Q62186
# Protein Name Joined...
# Processing... 695 : Q8R5J9
# Protein Name Joined...
# Processing... 696 : P61358
# Protein Name Joined...
# Processing... 697 : Q8BFZ3
# Protein Name Joined...
# Processing... 698 : Q9R111
# Protein Name Joined...
# Processing... 699 : P70441
# Protein Name Joined...
# Processing... 700 : B1ARA3
# Protein Name Joined...
# Processing... 701 : Q8BT60
# Protein Name Joined...
# Processing... 702 : Q9EST5
# Protein Name Joined...
# Processing... 703 : Q76MZ3
# Protein Name Joined...
# Processing... 704 : Q80UM7
# Protein Name Joined...
# Processing... 705 : Q9D6M3
# Protein Name Joined...
# Processing... 706 : P32067
# Protein Name Joined...
# Processing... 707 : Q68FD5
# Protein Name Joined...
# Processing... 708 : P11714
# Protein Name Joined...
# Processing... 709 : Q91ZJ5
# Protein Name Joined...
# Processing... 710 : O55022
# Protein Name Joined...
# Processing... 711 : Q91V64
# Protein Name Joined...
# Processing... 712 : O55135
# Protein Name Joined...
# Processing... 713 : Q9JJU8
# Protein Name Joined...
# Processing... 714 : P80317
# Protein Name Joined...
# Processing... 715 : A0A0R4J0N7
# Protein Name Joined...
# Processing... 716 : P52503
# Protein Name Joined...
# Processing... 717 : Q9Z1Z0
# Protein Name Joined...
# Processing... 718 : A2A5R2
# Protein Name Joined...
# Processing... 719 : Q9CXN7
# Protein Name Joined...
# Processing... 720 : Q99KV1
# Protein Name Joined...
# Processing... 721 : Q91VI7
# Protein Name Joined...
# Processing... 722 : P70168
# Protein Name Joined...
# Processing... 723 : Q9WV55
# Protein Name Joined...
# Processing... 724 : Q64737
# Protein Name Joined...
# Processing... 725 : A8DUK4
# Protein Name Joined...
# Processing... 726 : P32233
# Protein Name Joined...
# Processing... 727 : E9Q0U7
# Protein Name Joined...
# Processing... 728 : Q9D024
# Protein Name Joined...
# Processing... 729 : Q3TCD4
# Protein Name Joined...
# Processing... 730 : Q9R092
# Protein Name Joined...
# Processing... 731 : B7ZD61
# Protein Name Joined...
# Processing... 732 : Q9CQS8
# Protein Name Joined...
# Processing... 733 : E9Q1Y3
# Protein Name Joined...
# Processing... 734 : P34914
# Protein Name Joined...
# Processing... 735 : Q8BWQ1
# Protein Name Joined...
# Processing... 736 : P20918
# Protein Name Joined...
# Processing... 737 : Q8R4N0
# Protein Name Joined...
# Processing... 738 : P61161
# Protein Name Joined...
# Processing... 739 : P10126
# Protein Name Joined...
# Processing... 740 : Q9DCS3
# Protein Name Joined...
# Processing... 741 : A2AKD6
# Protein Name Joined...
# Processing... 742 : Q9CZ44
# Protein Name Joined...
# Processing... 743 : P14115
# Protein Name Joined...
# Processing... 744 : P26638
# Protein Name Joined...
# Processing... 745 : P62242
# Protein Name Joined...
# Processing... 746 : A0A0R4J1H2
# Protein Name Joined...
# Processing... 747 : Q9WVJ2
# Protein Name Joined...
# Processing... 748 : P01029
# Protein Name Joined...
# Processing... 749 : P28063
# Protein Name Joined...
# Processing... 750 : P57780
# Protein Name Joined...
# Processing... 751 : Q923D2
# Protein Name Joined...
# Processing... 752 : Q8BFY9
# Protein Name Joined...
# Processing... 753 : Q9D172
# Protein Name Joined...
# Processing... 754 : Q99L04
# Protein Name Joined...
# Processing... 755 : Q9DD20
# Protein Name Joined...
# Processing... 756 : Q91VM9
# Protein Name Joined...
# Processing... 757 : Q3TXN1
# Protein Name Joined...
# Processing... 758 : Q9WU79
# Protein Name Joined...
# Processing... 759 : Q8K183
# Protein Name Joined...
# Processing... 760 : Q01339
# Protein Name Joined...
# Processing... 761 : O35857
# Protein Name Joined...
# Processing... 762 : P19783
# Protein Name Joined...
# Processing... 763 : Q6P4T2
# Protein Name Joined...
# Processing... 764 : A0A0A6YX18
# Protein Name Joined...
# Processing... 765 : Q3ULJ0
# Protein Name Joined...
# Processing... 766 : D3Z041
# Protein Name Joined...
# Processing... 767 : Q9D0I9
# Protein Name Joined...
# Processing... 768 : O88736
# Protein Name Joined...
# Processing... 769 : Q921X9
# Protein Name Joined...
# Processing... 770 : P51410
# Protein Name Joined...
# Processing... 771 : Q9JHJ0
# Protein Name Joined...
# Processing... 772 : Q3U0B3
# Protein Name Joined...
# Processing... 773 : Q99L88
# Protein Name Joined...
# Processing... 774 : Q9ET30
# Protein Name Joined...
# Processing... 775 : P47791
# Protein Name Joined...
# Processing... 776 : A0A2R8VHN3
# Protein Name Joined...
# Processing... 777 : P26039
# Protein Name Joined...
# Processing... 778 : P62075
# Protein Name Joined...
# Processing... 779 : Q922B2
# Protein Name Joined...
# Processing... 780 : P11983
# Protein Name Joined...
# Processing... 781 : Q8BH00
# Protein Name Joined...
# Processing... 782 : E9Q4K7
# Protein Name Joined...
# Processing... 783 : P24549
# Protein Name Joined...
# Processing... 784 : Q99K28
# Protein Name Joined...
# Processing... 785 : Q8VDD5
# Protein Name Joined...
# Processing... 786 : Q9CQR6
# Protein Name Joined...
# Processing... 787 : Q5FW57
# Protein Name Joined...
# Processing... 788 : Q9WV98
# Protein Name Joined...
# Processing... 789 : Q8CFJ7
# Protein Name Joined...
# Processing... 790 : Q3U1J4
# Protein Name Joined...
# Processing... 791 : Q9D8E6
# Protein Name Joined...
# Processing... 792 : Q9D1Q6
# Protein Name Joined...
# Processing... 793 : P61027
# Protein Name Joined...
# Processing... 794 : Q9CR57
# Protein Name Joined...
# Processing... 795 : K9J7B2
# Protein Name Joined...
# Processing... 796 : Q9JK42
# Protein Name Joined...
# Processing... 797 : D3YTY9
# Protein Name Joined...
# Processing... 798 : A0A0N4SV32
# Protein Name Joined...
# Processing... 799 : G5E8R3
# Protein Name Joined...
# Processing... 800 : Q91VB8
# Protein Name Joined...
# Processing... 801 : P09055
# Protein Name Joined...
# Processing... 802 : P97450
# Protein Name Joined...
# Processing... 803 : Q8R010
# Protein Name Joined...
# Processing... 804 : P68372
# Protein Name Joined...
# Processing... 805 : Q9Z1J3
# Protein Name Joined...
# Processing... 806 : F6QCI0
# Protein Name Joined...
# Processing... 807 : Q03265
# Protein Name Joined...
# Processing... 808 : A0A1L1SQA8
# Protein Name Joined...
# Processing... 809 : Q8BH86
# Protein Name Joined...
# Processing... 810 : Q9CPX6
# Protein Name Joined...
# Processing... 811 : Q9QYA2
# Protein Name Joined...
# Processing... 812 : Q8K0E8
# Protein Name Joined...
# Processing... 813 : P05201
# Protein Name Joined...
# Processing... 814 : Q91W43
# Protein Name Joined...
# Processing... 815 : Q8K441
# Protein Name Joined...
# Processing... 816 : P63038
# Protein Name Joined...
# Processing... 817 : Q9JKR6
# Protein Name Joined...
# Processing... 818 : Q8K2B3
# Protein Name Joined...
# Processing... 819 : P31230
# Protein Name Joined...
# Processing... 820 : E9Q4M8
# Protein Name Joined...
# Processing... 821 : Q8VC12
# Protein Name Joined...
# Processing... 822 : Q9EQH2
# Protein Name Joined...
# Processing... 823 : O55142
# Protein Name Joined...
# Processing... 824 : A0A087WQE6
# Protein Name Joined...
# Processing... 825 : Q61035
# Protein Name Joined...
# Processing... 826 : P80313
# Protein Name Joined...
# Processing... 827 : Q9DBT9
# Protein Name Joined...
# Processing... 828 : Q9DCD0
# Protein Name Joined...
# Processing... 829 : O55143
# Protein Name Joined...
# Processing... 830 : P50544
# Protein Name Joined...
# Processing... 831 : Q9CPU0
# Protein Name Joined...
# Processing... 832 : F7CBP1
# Protein Name Joined...
# Processing... 833 : Q8BGQ7
# Protein Name Joined...
# Processing... 834 : Q60854
# Protein Name Joined...
# Processing... 835 : Q8BJY1
# Protein Name Joined...
# Processing... 836 : Q8CGC7
# Protein Name Joined...
# Processing... 837 : P63005
# Protein Name Joined...
# Processing... 838 : Q9ER72
# Protein Name Joined...
# Processing... 839 : Q9CQA3
# Protein Name Joined...
# Processing... 840 : Q6ZWX6
# Protein Name Joined...
# Processing... 841 : Q3UEP4
# Protein Name Joined...
# Processing... 842 : Q9WVA4
# Protein Name Joined...
# Processing... 843 : Q8C2Q8
# Protein Name Joined...
# Processing... 844 : F6QTS1
# Protein Name Joined...
# Processing... 845 : P28665
# Protein Name Joined...
# Processing... 846 : A0A140LJG4
# Protein Name Joined...
# Processing... 847 : P62806
# Protein Name Joined...
# Processing... 848 : A0A338P703
# Protein Name Joined...
# Processing... 849 : O35350
# Protein Name Joined...
# Processing... 850 : Q8R1G2
# Protein Name Joined...
# Processing... 851 : P68040
# Protein Name Joined...
# Processing... 852 : Q99LF4
# Protein Name Joined...
# Processing... 853 : P70122
# Protein Name Joined...
# Processing... 854 : Q7M6Y3
# Protein Name Joined...
# Processing... 855 : A2CEK7
# Protein Name Joined...
# Processing... 856 : Q9D0F9
# Protein Name Joined...
# Processing... 857 : A0A0A6YVR9
# Protein Name Joined...
# Processing... 858 : P70333
# Protein Name Joined...
# Processing... 859 : Q8BFR5
# Protein Name Joined...
# Processing... 860 : P62331
# Protein Name Joined...
# Processing... 861 : Q8BRF7
# Protein Name Joined...
# Processing... 862 : Q6GT24
# Protein Name Joined...
# Processing... 863 : Q8K370
# Protein Name Joined...
# Processing... 864 : Q00519
# Protein Name Joined...
# Processing... 865 : Q924B0
# Protein Name Joined...
# Processing... 866 : Q8CI32
# Protein Name Joined...
# Processing... 867 : F6TVP2
# Protein Name Joined...
# Processing... 868 : Q8R164
# Protein Name Joined...
# Processing... 869 : Q9DCQ2
# Protein Name Joined...
# Processing... 870 : Q9JJ28
# Protein Name Joined...
# Processing... 871 : Q8VEK3
# Protein Name Joined...
# Processing... 872 : Q8BMA6
# Protein Name Joined...
# Processing... 873 : Q6ZWV7
# Protein Name Joined...
# Processing... 874 : P80315
# Protein Name Joined...
# Processing... 875 : Q8BWF0
# Protein Name Joined...
# Processing... 876 : Q8VI47
# Protein Name Joined...
# Processing... 877 : P46460
# Protein Name Joined...
# Processing... 878 : P08003
# Protein Name Joined...
# Processing... 879 : Q96LX3
# Protein Name Joined...
# Processing... 880 : B1AU25
# Protein Name Joined...
# Processing... 881 : P58281
# Protein Name Joined...
# Processing... 882 : P60867
# Protein Name Joined...
# Processing... 883 : Q99PG0
# Protein Name Joined...
# Processing... 884 : Q8BPI2
# Protein Name Joined...
# Processing... 885 : P47962
# Protein Name Joined...
# Processing... 886 : Q9D967
# Protein Name Joined...
# Processing... 887 : Q5SWU9
# Protein Name Joined...
# Processing... 888 : P63276
# Protein Name Joined...
# Processing... 889 : P61089
# Protein Name Joined...
# Processing... 890 : O88441
# Protein Name Joined...
# Processing... 891 : Q99KI0
# Protein Name Joined...
# Processing... 892 : Q9ET01
# Protein Name Joined...
# Processing... 893 : H3BKN0
# Protein Name Joined...
# Processing... 894 : Q91WQ3
# Protein Name Joined...
# Processing... 895 : P17751
# Protein Name Joined...
# Processing... 896 : Q9WUM5
# Protein Name Joined...
# Processing... 897 : Q61081
# Protein Name Joined...
# Processing... 898 : Q791V5
# Protein Name Joined...
# Processing... 899 : Q9DBG1
# Protein Name Joined...
# Processing... 900 : Q6ZQ38
# Protein Name Joined...
# Processing... 901 : Q9CQZ6
# Protein Name Joined...
# Processing... 902 : E9Q6R7
# Protein Name Joined...
# Processing... 903 : Q9D273
# Protein Name Joined...
# Processing... 904 : P26150
# Protein Name Joined...
# Processing... 905 : Q9R0H0
# Protein Name Joined...
# Processing... 906 : P03911
# Protein Name Joined...
# Processing... 907 : P35762
# Protein Name Joined...
# Processing... 908 : A0A1Y7VJY8
# Protein Name Joined...
# Processing... 909 : Q99P72
# Protein Name Joined...
# Processing... 910 : P63028
# Protein Name Joined...
# Processing... 911 : Q06185
# Protein Name Joined...
# Processing... 912 : Q71RI9
# Protein Name Joined...
# Processing... 913 : P84078
# Protein Name Joined...
# Processing... 914 : B7FAV1
# Protein Name Joined...
# Processing... 915 : Q80WJ7
# Protein Name Joined...
# Processing... 916 : Q9DBH5
# Protein Name Joined...
# Processing... 917 : E9Q035
# Protein Name Joined...
# Processing... 918 : Q8BMS1
# Protein Name Joined...
# Processing... 919 : Q8BK48
# Protein Name Joined...
# Processing... 920 : P43274
# Protein Name Joined...
# Processing... 921 : P42669
# Protein Name Joined...
# Processing... 922 : Q3UNX5
# Protein Name Joined...
# Processing... 923 : Q91YI0
# Protein Name Joined...
# Processing... 924 : Q78JT3
# Protein Name Joined...
# Processing... 925 : P28271
# Protein Name Joined...
# Processing... 926 : A0A0R4J069
# Protein Name Joined...
# Processing... 927 : A0A0R4J1V0
# Protein Name Joined...
# Processing... 928 : Q6PB66
# Protein Name Joined...
# Processing... 929 : P10630
# Protein Name Joined...
# Processing... 930 : Q9WU19
# Protein Name Joined...
# Processing... 931 : O88342
# Protein Name Joined...
# Processing... 932 : P97807
# Protein Name Joined...
# Processing... 933 : Q8BL66
# Protein Name Joined...
# Processing... 934 : Q8K157
# Protein Name Joined...
# Processing... 935 : Q8C5H8
# Protein Name Joined...
# Processing... 936 : P19536
# Protein Name Joined...
# Processing... 937 : P56480
# Protein Name Joined...
# Processing... 938 : Q5FW60
# Protein Name Joined...
# Processing... 939 : Q922D8
# Protein Name Joined...
# Processing... 940 : P19221
# Protein Name Joined...
# Processing... 941 : Q9WUU7
# Protein Name Joined...
# Processing... 942 : H3BJ71
# Protein Name Joined...
# Processing... 943 : P61458
# Protein Name Joined...
# Processing... 944 : Q9WUA2
# Protein Name Joined...
# Processing... 945 : P59325
# Protein Name Joined...
# Processing... 946 : A2AVJ7
# Protein Name Joined...
# Processing... 947 : P80318
# Protein Name Joined...
# Processing... 948 : Q9CR62
# Protein Name Joined...
# Processing... 949 : Q64442
# Protein Name Joined...
# Processing... 950 : P14094
# Protein Name Joined...
# Processing... 951 : G3UZ26
# Protein Name Joined...
# Processing... 952 : Q60737
# Protein Name Joined...
# Processing... 953 : Q80X90
# Protein Name Joined...
# Processing... 954 : Q99KQ4
# Protein Name Joined...
# Processing... 955 : P62301
# Protein Name Joined...
# Processing... 956 : Q62189
# Protein Name Joined...
# Processing... 957 : P97364
# Protein Name Joined...
# ...
# Protein Name Joined...
# Processing... 1969 : Q6XPS7
# Protein Name Joined...
# Processing... 1970 : Q6XVG2
# Protein Name Joined...
# Processing... 1971 : Q71LX4
# Protein Name Joined...
# Processing... 1972 : Q78JE5
# Protein Name Joined...
# Processing... 1973 : Q78KK3
# Protein Name Joined...
# Processing... 1974 : Q7M739
# Protein Name Joined...
# Processing... 1975 : Q7TMC8
# Protein Name Joined...
# Processing... 1976 : Q7TMY8
# Protein Name Joined...
# Processing... 1977 : Q7TN29
# Protein Name Joined...
# Processing... 1978 : Q7TNV0
# Protein Name Joined...
# Processing... 1979 : Q7TSV4
# Protein Name Joined...
# Processing... 1980 : Q7TT50
# Protein Name Joined...
# Processing... 1981 : Q80TM9
# Protein Name Joined...
# Processing... 1982 : Q80VJ3
# Protein Name Joined...
# Processing... 1983 : Q80VP1
# Protein Name Joined...
# Processing... 1984 : Q80W21
# Protein Name Joined...
# Processing... 1985 : Q810B6
# Protein Name Joined...
# Processing... 1986 : Q811U4
# Protein Name Joined...
# Processing... 1987 : Q8BFQ8
# Protein Name Joined...
# Processing... 1988 : Q8BFW7
# Protein Name Joined...
# Processing... 1989 : Q8BFY6
# Protein Name Joined...
# Processing... 1990 : Q8BG51
# Protein Name Joined...
# Processing... 1991 : Q8BGC4
# Protein Name Joined...
# Processing... 1992 : Q8BGD9
# Protein Name Joined...
# Processing... 1993 : Q8BGS1
# Protein Name Joined...
# Processing... 1994 : Q8BGS2
# Protein Name Joined...
# Processing... 1995 : Q8BGW1
# Protein Name Joined...
# Processing... 1996 : Q8BH58
# Protein Name Joined...
# Processing... 1997 : Q8BH69
# Protein Name Joined...
# Processing... 1998 : Q8BHC4
# Protein Name Joined...
# Processing... 1999 : Q8BHD7
# Protein Name Joined...
# Processing... 2000 : Q8BHL8
# Protein Name Joined...
# Processing... 2001 : Q8BIW1
# Protein Name Joined...
# Processing... 2002 : Q8BJ71
# Protein Name Joined...
# Processing... 2003 : Q8BKC5
# Protein Name Joined...
# Processing... 2004 : Q8BMJ3
# Protein Name Joined...
# Processing... 2005 : Q8BNI4
# Protein Name Joined...
# Processing... 2006 : Q8BP40
# Protein Name Joined...
# Processing... 2007 : Q8BRQ9
# Protein Name Joined...
# Processing... 2008 : Q8BS35
# Protein Name Joined...
# Processing... 2009 : Q8BTZ7
# Protein Name Joined...
# Processing... 2010 : Q8BUK6
# Protein Name Joined...
# Processing... 2011 : Q8BVG4
# Protein Name Joined...
# Processing... 2012 : Q8BWG8
# Protein Name Joined...
# Processing... 2013 : Q8BWN8
# Protein Name Joined...
# Processing... 2014 : Q8BX02
# Protein Name Joined...
# Processing... 2015 : Q8BX70
# Protein Name Joined...
# Processing... 2016 : Q8BXB6
# Protein Name Joined...
# Processing... 2017 : Q8BXV2
# Protein Name Joined...
# Processing... 2018 : Q8BXZ1
# Protein Name Joined...
# Processing... 2019 : Q8BYC6
# Protein Name Joined...
# Processing... 2020 : Q8BYK6
# Protein Name Joined...
# Processing... 2021 : Q8BZ09
# Protein Name Joined...
# Processing... 2022 : Q8BZW8
# Protein Name Joined...
# Processing... 2023 : Q8C025
# Protein Name Joined...
# Processing... 2024 : Q8C0D5
# Protein Name Joined...
# Processing... 2025 : Q8C3V4
# Protein Name Joined...
# Processing... 2026 : Q8C5W3
# Protein Name Joined...
# Processing... 2027 : Q8C6I2
# Protein Name Joined...
# Processing... 2028 : Q8C7E7
# Protein Name Joined...
# Processing... 2029 : Q8C7G5
# Protein Name Joined...
# Processing... 2030 : Q8C7H1
# Protein Name Joined...
# Processing... 2031 : Q8C845
# Protein Name Joined...
# Processing... 2032 : Q8CAK1
# Protein Name Joined...
# Processing... 2033 : Q8CAP3
# Protein Name Joined...
# Processing... 2034 : Q8CAS9
# Protein Name Joined...
# Processing... 2035 : Q8CAY6
# Protein Name Joined...
# Processing... 2036 : Q8CBY8
# Protein Name Joined...
# Processing... 2037 : Q8CCJ3
# Protein Name Joined...
# Processing... 2038 : Q8CCM0
# Protein Name Joined...
# Processing... 2039 : Q8CGA0
# Protein Name Joined...
# Processing... 2040 : Q8CGF5
# Protein Name Joined...
# Processing... 2041 : Q8CGY8
# Protein Name Joined...
# Processing... 2042 : Q8CH18
# Protein Name Joined...
# Processing... 2043 : Q8CHK3
# Protein Name Joined...
# Processing... 2044 : Q8CHP8
# Protein Name Joined...
# Processing... 2045 : Q8CI94
# Protein Name Joined...
# Processing... 2046 : Q8JZN7
# Protein Name Joined...
# Processing... 2047 : Q8JZQ2
# Protein Name Joined...
# Processing... 2048 : Q8JZR2
# Protein Name Joined...
# Processing... 2049 : Q8K2C8
# Protein Name Joined...
# Processing... 2050 : Q8K2I9
# Protein Name Joined...
# Processing... 2051 : Q8K2M0
# Protein Name Joined...
# Processing... 2052 : Q8K2Q0
# Protein Name Joined...
# Processing... 2053 : Q8K2Q9
# Protein Name Joined...
# Processing... 2054 : Q8K3J1
# Protein Name Joined...
# Processing... 2055 : Q8K3M1
# Protein Name Joined...
# Processing... 2056 : Q8K3W0
# Protein Name Joined...
# Processing... 2057 : Q8K4Z3
# Protein Name Joined...
# Processing... 2058 : Q8K4Z5
# Protein Name Joined...
# Processing... 2059 : Q8K5B2
# Protein Name Joined...
# Processing... 2060 : Q8QZR1
# Protein Name Joined...
# Processing... 2061 : Q8R059
# Protein Name Joined...
# Processing... 2062 : Q8R0Y8
# Protein Name Joined...
# Processing... 2063 : Q8R104
# Protein Name Joined...
# Processing... 2064 : Q8R180
# Protein Name Joined...
# Processing... 2065 : Q8R1G5
# Protein Name Joined...
# Processing... 2066 : Q8R2Y0
# Protein Name Joined...
# Processing... 2067 : Q8R317
# Protein Name Joined...
# Processing... 2068 : Q8R3F5
# Protein Name Joined...
# Processing... 2069 : Q8R4U0
# Protein Name Joined...
# Processing... 2070 : Q8R570
# Protein Name Joined...
# Processing... 2071 : Q8R5H1
# Protein Name Joined...
# Processing... 2072 : Q8VBT9
# Protein Name Joined...
# Processing... 2073 : Q8VC77
# Protein Name Joined...
# Processing... 2074 : Q8VCA8
# Protein Name Joined...
# Processing... 2075 : Q8VCC1
# Protein Name Joined...
# Processing... 2076 : Q8VCF0
# Protein Name Joined...
# Processing... 2077 : Q8VCH7
# Protein Name Joined...
# Processing... 2078 : Q8VCI5
# Protein Name Joined...
# Processing... 2079 : Q8VCU1
# Protein Name Joined...
# Processing... 2080 : Q8VDG5
# Protein Name Joined...
# Processing... 2081 : Q8VDG7
# Protein Name Joined...
# Processing... 2082 : Q8VDP4
# Protein Name Joined...
# Processing... 2083 : Q8VE95
# Protein Name Joined...
# Processing... 2084 : Q8VE97
# Protein Name Joined...
# Processing... 2085 : Q8VEE0
# Protein Name Joined...
# Processing... 2086 : Q8VHK9
# Protein Name Joined...
# Processing... 2087 : Q91V01
# Protein Name Joined...
# Processing... 2088 : Q91V04
# Protein Name Joined...
# Processing... 2089 : Q91V12
# Protein Name Joined...
# Processing... 2090 : Q91VC9
# Protein Name Joined...
# Processing... 2091 : Q91VF2
# Protein Name Joined...
# Processing... 2092 : Q91VH2
# Protein Name Joined...
# Processing... 2093 : Q91VH6
# Protein Name Joined...
# Processing... 2094 : Q91WK1
# Protein Name Joined...
# Processing... 2095 : Q91WM2
# Protein Name Joined...
# Processing... 2096 : Q91WU5
# Protein Name Joined...
# Processing... 2097 : Q91XD6
# Protein Name Joined...
# Processing... 2098 : Q91XD7
# Protein Name Joined...
# Processing... 2099 : Q91XL1
# Protein Name Joined...
# Processing... 2100 : Q91YR7
# Protein Name Joined...
# Processing... 2101 : Q91YZ8
# Protein Name Joined...
# Processing... 2102 : Q91ZW3
# Protein Name Joined...
# Processing... 2103 : Q920L1
# Protein Name Joined...
# Processing... 2104 : Q921F4
# Protein Name Joined...
# Processing... 2105 : Q921H9
# Protein Name Joined...
# Processing... 2106 : Q921K2
# Protein Name Joined...
# Processing... 2107 : Q921L3
# Protein Name Joined...
# Processing... 2108 : Q921S7
# Protein Name Joined...
# Processing... 2109 : Q921W4
# Protein Name Joined...
# Processing... 2110 : Q922B1
# Protein Name Joined...
# Processing... 2111 : Q922D4
# Protein Name Joined...
# Processing... 2112 : Q922H4
# Protein Name Joined...
# Processing... 2113 : Q922Y1
# Protein Name Joined...
# Processing... 2114 : Q923D4
# Protein Name Joined...
# Processing... 2115 : Q924L1
# Protein Name Joined...
# Processing... 2116 : Q924T2
# Protein Name Joined...
# Processing... 2117 : Q925N2
# Protein Name Joined...
# Processing... 2118 : Q99J27
# Protein Name Joined...
# Processing... 2119 : Q99J56
# Protein Name Joined...
# Processing... 2120 : Q99JR1
# Protein Name Joined...
# Processing... 2121 : Q99JW4
# Protein Name Joined...
# Processing... 2122 : Q99JY3
# Protein Name Joined...
# Processing... 2123 : Q99K41
# Protein Name Joined...
# Processing... 2124 : Q99KC8
# Protein Name Joined...
# Processing... 2125 : Q99KJ8
# Protein Name Joined...
# Processing... 2126 : Q99KK1
# Protein Name Joined...
# Processing... 2127 : Q99KP3
# Protein Name Joined...
# Processing... 2128 : Q99KP6
# Protein Name Joined...
# Processing... 2129 : Q99LB6
# Protein Name Joined...
# Processing... 2130 : Q99LC9
# Protein Name Joined...
# Processing... 2131 : Q99LD4
# Protein Name Joined...
# Processing... 2132 : Q99LD8
# Protein Name Joined...
# Processing... 2133 : Q99LD9
# Protein Name Joined...
# Processing... 2134 : Q99LG2
# Protein Name Joined...
# Processing... 2135 : Q99LP6
# Protein Name Joined...
# Processing... 2136 : Q99MR6
# Protein Name Joined...
# Processing... 2137 : Q99N84
# Protein Name Joined...
# Processing... 2138 : Q99N87
# Protein Name Joined...
# Processing... 2139 : Q99N94
# Protein Name Joined...
# Processing... 2140 : Q99NF1
# Protein Name Joined...
# Processing... 2141 : Q99PT1
# Protein Name Joined...
# Processing... 2142 : Q9CPQ3
# Protein Name Joined...
# Processing... 2143 : Q9CQ60
# Protein Name Joined...
# Processing... 2144 : Q9CQ65
# Protein Name Joined...
# Processing... 2145 : Q9CQF0
# Protein Name Joined...
# Processing... 2146 : Q9CQI3
# Protein Name Joined...
# Processing... 2147 : Q9CQK7
# Protein Name Joined...
# Processing... 2148 : Q9CQT1
# Protein Name Joined...
# Processing... 2149 : Q9CQV1
# Protein Name Joined...
# Processing... 2150 : Q9CQX2
# Protein Name Joined...
# Processing... 2151 : Q9CR00
# Protein Name Joined...
# Processing... 2152 : Q9CRB2
# Protein Name Joined...
# Processing... 2153 : Q9CRB8
# Protein Name Joined...
# Processing... 2154 : Q9CRD2
# Protein Name Joined...
# Processing... 2155 : Q9CWD8
# Protein Name Joined...
# Processing... 2156 : Q9CWU3
# Protein Name Joined...
# Processing... 2157 : Q9CX00
# Protein Name Joined...
# Processing... 2158 : Q9CX98
# Protein Name Joined...
# Processing... 2159 : Q9CXV1
# Protein Name Joined...
# Processing... 2160 : Q9CXW2
# Protein Name Joined...
# Processing... 2161 : Q9CY73
# Protein Name Joined...
# Processing... 2162 : Q9CYA0
# Protein Name Joined...
# Processing... 2163 : Q9CYS6
# Protein Name Joined...
# Processing... 2164 : Q9CYV5
# Protein Name Joined...
# Processing... 2165 : Q9CZ04
# Protein Name Joined...
# Processing... 2166 : Q9CZ83
# Protein Name Joined...
# Processing... 2167 : Q9CZD3
# Protein Name Joined...
# Processing... 2168 : Q9CZE3
# Protein Name Joined...
# Processing... 2169 : Q9CZP5
# Protein Name Joined...
# Processing... 2170 : Q9CZX9
# Protein Name Joined...
# Processing... 2171 : Q9D071
# Protein Name Joined...
# Processing... 2172 : Q9D0B5
# Protein Name Joined...
# Processing... 2173 : Q9D0G0
# Protein Name Joined...
# Processing... 2174 : Q9D0M1
# Protein Name Joined...
# Processing... 2175 : Q9D0M5
# Protein Name Joined...
# Processing... 2176 : Q9D0Q7
# Protein Name Joined...
# Processing... 2177 : Q9D0S9
# Protein Name Joined...
# Processing... 2178 : Q9D104
# Protein Name Joined...
# Processing... 2179 : Q9D187
# Protein Name Joined...
# Processing... 2180 : Q9D1F9
# Protein Name Joined...
# Processing... 2181 : Q9D1L0
# Protein Name Joined...
# Processing... 2182 : Q9D1N9
# Protein Name Joined...
# Processing... 2183 : Q9D1R9
# Protein Name Joined...
# Processing... 2184 : Q9D281
# Protein Name Joined...
# Processing... 2185 : Q9D2V7
# Protein Name Joined...
# Processing... 2186 : Q9D338
# Protein Name Joined...
# Processing... 2187 : Q9D4H8
# Protein Name Joined...
# Processing... 2188 : Q9D554
# Protein Name Joined...
# Processing... 2189 : Q9D6J5
# Protein Name Joined...
# Processing... 2190 : Q9D6U8
# Protein Name Joined...
# Processing... 2191 : Q9D787
# Protein Name Joined...
# Processing... 2192 : Q9D7M1
# Protein Name Joined...
# Processing... 2193 : Q9D7X3
# Protein Name Joined...
# Processing... 2194 : Q9D898
# Protein Name Joined...
# Processing... 2195 : Q9D8B4
# Protein Name Joined...
# Processing... 2196 : Q9D8S9
# Protein Name Joined...
# Processing... 2197 : Q9D8U8
# Protein Name Joined...
# Processing... 2198 : Q9DAC2
# Protein Name Joined...
# Processing... 2199 : Q9DAW6
# Protein Name Joined...
# Processing... 2200 : Q9DB25
# Protein Name Joined...
# Processing... 2201 : Q9DB27
# Protein Name Joined...
# Processing... 2202 : Q9DBC7
# Protein Name Joined...
# Processing... 2203 : Q9DBE8
# Protein Name Joined...
# Processing... 2204 : Q9DBG5
# Protein Name Joined...
# Processing... 2205 : Q9DBS5
# Protein Name Joined...
# Processing... 2206 : Q9DBZ5
# Protein Name Joined...
# Processing... 2207 : Q9DC51
# Protein Name Joined...
# Processing... 2208 : Q9DCC4
# Protein Name Joined...
# Processing... 2209 : Q9DCE9
# Protein Name Joined...
# Processing... 2210 : Q9DCN1
# Protein Name Joined...
# Processing... 2211 : Q9DCZ4
# Protein Name Joined...
# Processing... 2212 : Q9EP75
# Protein Name Joined...
# Processing... 2213 : Q9EPU0
# Protein Name Joined...
# Processing... 2214 : Q9EQC1
# Protein Name Joined...
# Processing... 2215 : Q9EQI8
# Protein Name Joined...
# Processing... 2216 : Q9EQS3
# Protein Name Joined...
# Processing... 2217 : Q9ER88
# Protein Name Joined...
# Processing... 2218 : Q9ERB0
# Protein Name Joined...
# Processing... 2219 : Q9ERE7
# Protein Name Joined...
# Processing... 2220 : Q9ERU9
# Protein Name Joined...
# Processing... 2221 : Q9ERY9
# Protein Name Joined...
# Processing... 2222 : Q9ESB3
# Protein Name Joined...
# Processing... 2223 : Q9ESW4
# Protein Name Joined...
# Processing... 2224 : Q9ESX5
# Protein Name Joined...
# Processing... 2225 : Q9ET22
# Protein Name Joined...
# Processing... 2226 : Q9JI39
# Protein Name Joined...
# Processing... 2227 : Q9JIK9
# Protein Name Joined...
# Processing... 2228 : Q9JIM1
# Protein Name Joined...
# Processing... 2229 : Q9JJL8
# Protein Name Joined...
# Processing... 2230 : Q9JK81
# Protein Name Joined...
# Processing... 2231 : Q9JKF7
# Protein Name Joined...
# Processing... 2232 : Q9JKY5
# Protein Name Joined...
# Processing... 2233 : Q9JL15
# Protein Name Joined...
# Processing... 2234 : Q9JLB0
# Protein Name Joined...
# Processing... 2235 : Q9JLI0
# Protein Name Joined...
# Processing... 2236 : Q9JLV1
# Protein Name Joined...
# Processing... 2237 : Q9JLV5
# Protein Name Joined...
# Processing... 2238 : Q9JM14
# Protein Name Joined...
# Processing... 2239 : Q9QWG7
# Protein Name Joined...
# Processing... 2240 : Q9QWR8
# Protein Name Joined...
# Processing... 2241 : Q9QXB9
# Protein Name Joined...
# Processing... 2242 : Q9QXJ2
# Protein Name Joined...
# Processing... 2243 : Q9QXK3
# Protein Name Joined...
# Processing... 2244 : Q9QYB1
# Protein Name Joined...
# Processing... 2245 : Q9QYR7
# Protein Name Joined...
# Processing... 2246 : Q9QYR9
# Protein Name Joined...
# Processing... 2247 : Q9QZ23
# Protein Name Joined...
# Processing... 2248 : Q9QZM0
# Protein Name Joined...
# Processing... 2249 : Q9QZS5
# Protein Name Joined...
# Processing... 2250 : Q9QZX7
# Protein Name Joined...
# Processing... 2251 : Q9R049
# Protein Name Joined...
# Processing... 2252 : Q9R078
# Protein Name Joined...
# Processing... 2253 : Q9R0M5
# Protein Name Joined...
# Processing... 2254 : Q9R1T2
# Protein Name Joined...
# Processing... 2255 : Q9R233
# Protein Name Joined...
# Processing... 2256 : Q9WU84
# Protein Name Joined...
# Processing... 2257 : Q9WV54
# Protein Name Joined...
# Processing... 2258 : Q9WVA2
# Protein Name Joined...
# Processing... 2259 : Q9WVQ5
# Protein Name Joined...
# Processing... 2260 : Q9WVT6
# Protein Name Joined...
# Processing... 2261 : Q9Z0E6
# Protein Name Joined...
# Processing... 2262 : Q9Z0K8
# Protein Name Joined...
# Processing... 2263 : Q9Z0N1
# Protein Name Joined...
# Processing... 2264 : Q9Z1A1
# Protein Name Joined...
# Processing... 2265 : Q9Z1K6
# Protein Name Joined...
# Processing... 2266 : Q9Z1P6
# Protein Name Joined...
# Processing... 2267 : Q9Z1Q5
# Protein Name Joined...
# Processing... 2268 : Q9Z2A7
# Protein Name Joined...
# Processing... 2269 : Q9Z2G9
# Protein Name Joined...
# Processing... 2270 : S4R1E5
# Protein Name Joined...
# Processing... 2271 : S4R1V0
# Protein Name Joined...
# Processing... 2272 : V9GWT6
# Protein Name Joined...
# Processing... 2273 : V9GX08
# Protein Name Joined...
# Processing... 2274 : V9GX22
# Protein Name Joined...
# Processing... 2275 : V9GX87
# Protein Name Joined...
# Processing... 2276 : Z4YJR1
# Protein Name Joined...
# Processing... 2277 : Z4YJT3
# Protein Name Joined...
# Processing... 2278 : Z4YJW0
# Protein Name Joined...
# Processing... 2279 : Z4YKM2
# Protein Name Joined...
# Processing... 2280 : Z4YKT6
# Protein Name Joined...
# Processing... 2281 : Z4YKV1
# Protein Name Joined...

# %%
dictn = json_data["results"][34]["to"]

if dictn.get('proteinDescription') == None:
    print(dictn.get('inactiveReason'))

#pr_name = json_data["results"][34]["to"]["proteinDescription"]["submissionNames"][0]["fullName"]["value"]
# Out:
# {'inactiveReasonType': 'DELETED'}

# %%
# Recommended Name (5, )
n_try = 34

try:
    pr_name = json_data['results'][n_try]['to']['proteinDescription']['recommendedName']['fullName']['value']
except:
    pr_name = json_data['results'][n_try]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']

print(pr_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 5
#       4 try:
# ----> 5     pr_name = json_data['results'][n_try]['to']['proteinDescription']['recommendedName']['fullName']['value']
#       6 except:
#
# KeyError: 'proteinDescription'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 7
#       5     pr_name = json_data['results'][n_try]['to']['proteinDescription']['recommendedName']['fullName']['value']
#       6 except:
# ----> 7     pr_name = json_data['results'][n_try]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']
#       9 print(pr_name)
#
# KeyError: 'proteinDescription'

# %%
# Alternative Name (4, )
pr_name = json_data['results'][4]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
print(pr_name)
# Out:
# NADH dehydrogenase [ubiquinone] 1 alpha subcomplex assembly factor 1

# %%
# Protein Names
row_num = 7
rec_name = json_data['results'][row_num]['to']['proteinDescription']['recommendedName']['fullName']['value']
#alt_name = json_data['results'][row_num]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
sub_name = json_data['results'][row_num]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']

print(rec_name)
#print(alt_name)
print(sub_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
#       2 row_num = 7
#       3 #rec_name = json_data['results'][row_num]['to']['proteinDescription']['recommendedName']['fullName']['value']
# ----> 4 alt_name = json_data['results'][row_num]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
#       5 sub_name = json_data['results'][row_num]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']
#       7 #print(rec_name)
#
# KeyError: 'alternativeNames'

# %%
pr_from = json_data['results'][99]['from']
print(pr_from)
# Out:
# R4GML4

# %%
"""
# json_data['results'][int]['from']
# json_data['results'][int]['to']['proteinDescription']['recommendedName']['fullName']['value']
# json_data['results'][int]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
# json_data['results'][int]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']

Uniprot .json file structure by keys

results
    from
        Uniprot Accession ID
    to
        'entryType' : 'UniProtKB reviewed (Swiss-Prot)' OR 'UniProtKB unreviewed (TrEMBL)'
        'primaryAccession' : (Primary Accession ID)
        'uniProtkbId' : UniprotKB_MOUSE
        'entryAudit'
        'annotationScore'
        'organism'
            'scientificName'
            'commonName'
            'taxonId'
            'evidences'
                ['evidenceCode', 'source', 'id']
            'lineage'
        'proteinExistence'
        'proteinDescription'
            'recommendedName'
                'fullName'
                    'evidences'
                    ['evidenceCode', 'source', 'id'],
                    'value' <-- ***
            'alternativeNames'
            [
            'fullName'
                'evidences'
                ['evidenceCode', 'source', 'id'],
                'value' <-- ***
            ]
            'submissionNames'
            [
            'fullName'
                'evidences'
                ['evidenceCode', 'source', 'id']
                'value' <-- ***
            ]
        'genes'
        [
        'geneName'
            'evidences'
            ['evidenceCode', 'source', 'id'],
            'value'
        ]
        'features'
        'keywords'
        'references' <-- # of N from ['references'].__len__() 
        [
        'citation'
            'id'
            'citationType'
            'authors'
            'citationCrossReferences'
            'title'
            'publicationDate'
            'journal'
            'firstPage'
            'lastPage'
            'volume'
        'referencePositions'
        'referencecomments'
        'evidences'
        ]
        'uniProtKBCrossReferences'
        'sequence'
            'value' <-- ***
            'length'
            'molWeight'
            'crc64'
            'md5'
        'extraAttributes'
"""
# Out:
# 17242355
# 18630941
# 19144319
# 19468303
# 21183079
# CI-20IMGCHMHIQ52

# %%
num_sublist = json_data['results'][1]['to']['references'].__len__()

for i in range(num_sublist):
    keynames = json_data['results'][1]['to']['references'][i]['citation']
    PMID = keynames['id']
    print(PMID)

pr_names = json_data['results'][1]['to']['references'][0]['citation']
#print(pr_names)
# Out:
# 17242355
# 18630941
# 19144319
# 19468303
# 21183079
# CI-20IMGCHMHIQ52
